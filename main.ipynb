# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as pl
import seaborn as sn

# %%
data = pd.read_csv("energy.csv")

# %%
data
# Out:
#                Timestamp  Temperature   Humidity  SquareFootage  Occupancy  \
# 0    2022-01-01 00:00:00    25.139433  43.431581    1565.693999          5
# 1    2022-01-01 01:00:00    27.731651  54.225919    1411.064918          1
# 2    2022-01-01 02:00:00    28.704277  58.907658    1755.715009          2
# 3    2022-01-01 03:00:00    20.080469  50.371637    1452.316318          1
# 4    2022-01-01 04:00:00    23.097359  51.401421    1094.130359          9
# ..                   ...          ...        ...            ...        ...
# 995  2022-02-11 11:00:00    28.619382  48.850160    1080.087000          5
# 996  2022-02-11 12:00:00    23.836647  47.256435    1705.235156          4
# 997  2022-02-11 13:00:00    23.005340  48.720501    1320.285281          6
# 998  2022-02-11 14:00:00    25.138365  31.306459    1309.079719          3
# 999  2022-02-11 15:00:00    23.051165  42.615421    1018.140606          6
#
#     HVACUsage LightingUsage  RenewableEnergy  DayOfWeek Holiday  \
# 0          On           Off         2.774699     Monday      No
# 1          On            On        21.831384   Saturday      No
# 2         Off           Off         6.764672     Sunday      No
# 3         Off            On         8.623447  Wednesday      No
# 4          On           Off         3.071969     Friday      No
# ..        ...           ...              ...        ...     ...
# 995       Off           Off        21.194696   Saturday      No
# 996       Off            On        25.748176    Tuesday     Yes
# 997       Off            On         0.297079     Friday     Yes
# 998        On           Off        20.425163   Thursday     Yes
# 999       Off            On         2.455657   Saturday      No
#
#      EnergyConsumption
# 0            75.364373
# 1            83.401855
# 2            78.270888
# 3            56.519850
# 4            70.811732
# ..                 ...
# 995          82.306692
# 996          66.577320
# 997          72.753471
# 998          76.950389
# 999          71.545311
#
# [1000 rows x 11 columns]

# %% [markdown]
# #EDA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Timestamp          1000 non-null   object
#  1   Temperature        1000 non-null   float64
#  2   Humidity           1000 non-null   float64
#  3   SquareFootage      1000 non-null   float64
#  4   Occupancy          1000 non-null   int64
#  5   HVACUsage          1000 non-null   object
#  6   LightingUsage      1000 non-null   object
#  7   RenewableEnergy    1000 non-null   float64
#  8   DayOfWeek          1000 non-null   object
#  9   Holiday            1000 non-null   object
#  10  EnergyConsumption  1000 non-null   float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 86.1+ KB

# %%
#removes the null values
data.dropna(inplace = True)

# %%
data
# Out:
#                Timestamp  Temperature   Humidity  SquareFootage  Occupancy  \
# 0    2022-01-01 00:00:00    25.139433  43.431581    1565.693999          5
# 1    2022-01-01 01:00:00    27.731651  54.225919    1411.064918          1
# 2    2022-01-01 02:00:00    28.704277  58.907658    1755.715009          2
# 3    2022-01-01 03:00:00    20.080469  50.371637    1452.316318          1
# 4    2022-01-01 04:00:00    23.097359  51.401421    1094.130359          9
# ..                   ...          ...        ...            ...        ...
# 995  2022-02-11 11:00:00    28.619382  48.850160    1080.087000          5
# 996  2022-02-11 12:00:00    23.836647  47.256435    1705.235156          4
# 997  2022-02-11 13:00:00    23.005340  48.720501    1320.285281          6
# 998  2022-02-11 14:00:00    25.138365  31.306459    1309.079719          3
# 999  2022-02-11 15:00:00    23.051165  42.615421    1018.140606          6
#
#     HVACUsage LightingUsage  RenewableEnergy  DayOfWeek Holiday  \
# 0          On           Off         2.774699     Monday      No
# 1          On            On        21.831384   Saturday      No
# 2         Off           Off         6.764672     Sunday      No
# 3         Off            On         8.623447  Wednesday      No
# 4          On           Off         3.071969     Friday      No
# ..        ...           ...              ...        ...     ...
# 995       Off           Off        21.194696   Saturday      No
# 996       Off            On        25.748176    Tuesday     Yes
# 997       Off            On         0.297079     Friday     Yes
# 998        On           Off        20.425163   Thursday     Yes
# 999       Off            On         2.455657   Saturday      No
#
#      EnergyConsumption
# 0            75.364373
# 1            83.401855
# 2            78.270888
# 3            56.519850
# 4            70.811732
# ..                 ...
# 995          82.306692
# 996          66.577320
# 997          72.753471
# 998          76.950389
# 999          71.545311
#
# [1000 rows x 11 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Timestamp          1000 non-null   object
#  1   Temperature        1000 non-null   float64
#  2   Humidity           1000 non-null   float64
#  3   SquareFootage      1000 non-null   float64
#  4   Occupancy          1000 non-null   int64
#  5   HVACUsage          1000 non-null   object
#  6   LightingUsage      1000 non-null   object
#  7   RenewableEnergy    1000 non-null   float64
#  8   DayOfWeek          1000 non-null   object
#  9   Holiday            1000 non-null   object
#  10  EnergyConsumption  1000 non-null   float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 86.1+ KB

# %%
from sklearn.model_selection import train_test_split

x = data.drop(['EnergyConsumption'], axis=1 )
y = data['EnergyConsumption']

# %%
x
# Out:
#                Timestamp  Temperature   Humidity  SquareFootage  Occupancy  \
# 0    2022-01-01 00:00:00    25.139433  43.431581    1565.693999          5
# 1    2022-01-01 01:00:00    27.731651  54.225919    1411.064918          1
# 2    2022-01-01 02:00:00    28.704277  58.907658    1755.715009          2
# 3    2022-01-01 03:00:00    20.080469  50.371637    1452.316318          1
# 4    2022-01-01 04:00:00    23.097359  51.401421    1094.130359          9
# ..                   ...          ...        ...            ...        ...
# 995  2022-02-11 11:00:00    28.619382  48.850160    1080.087000          5
# 996  2022-02-11 12:00:00    23.836647  47.256435    1705.235156          4
# 997  2022-02-11 13:00:00    23.005340  48.720501    1320.285281          6
# 998  2022-02-11 14:00:00    25.138365  31.306459    1309.079719          3
# 999  2022-02-11 15:00:00    23.051165  42.615421    1018.140606          6
#
#     HVACUsage LightingUsage  RenewableEnergy  DayOfWeek Holiday
# 0          On           Off         2.774699     Monday      No
# 1          On            On        21.831384   Saturday      No
# 2         Off           Off         6.764672     Sunday      No
# 3         Off            On         8.623447  Wednesday      No
# 4          On           Off         3.071969     Friday      No
# ..        ...           ...              ...        ...     ...
# 995       Off           Off        21.194696   Saturday      No
# 996       Off            On        25.748176    Tuesday     Yes
# 997       Off            On         0.297079     Friday     Yes
# 998        On           Off        20.425163   Thursday     Yes
# 999       Off            On         2.455657   Saturday      No
#
# [1000 rows x 10 columns]

# %%
y
# Out:
# 0      75.364373
# 1      83.401855
# 2      78.270888
# 3      56.519850
# 4      70.811732
#          ...
# 995    82.306692
# 996    66.577320
# 997    72.753471
# 998    76.950389
# 999    71.545311
# Name: EnergyConsumption, Length: 1000, dtype: float64

# %%
x_train , x_test , y_train , y_test = train_test_split(x, y, test_size= 0.25)

# %%
train_data = x_train.join(y_train)

# %%
train_data
# Out:
#                Timestamp  Temperature   Humidity  SquareFootage  Occupancy  \
# 826  2022-02-04 10:00:00    29.052976  40.751437    1233.309971          2
# 507  2022-01-22 03:00:00    24.532160  50.026252    1913.064870          3
# 457  2022-01-20 01:00:00    22.514235  50.695972    1916.294314          9
# 281  2022-01-12 17:00:00    29.248673  48.087676    1025.039867          4
# 301  2022-01-13 13:00:00    29.672113  56.543907    1196.241144          8
# ..                   ...          ...        ...            ...        ...
# 516  2022-01-22 12:00:00    28.226551  55.031652    1186.695924          6
# 758  2022-02-01 14:00:00    20.225128  58.498654    1590.286479          5
# 789  2022-02-02 21:00:00    24.181085  50.476790    1871.148405          9
# 111  2022-01-05 15:00:00    29.257024  38.184267    1293.973980          1
# 972  2022-02-10 12:00:00    25.081029  31.303698    1555.747609          3
#
#     HVACUsage LightingUsage  RenewableEnergy  DayOfWeek Holiday  \
# 826        On            On        27.470798   Saturday     Yes
# 507        On           Off        14.108624  Wednesday      No
# 457        On           Off        13.500534     Sunday      No
# 281        On           Off        25.683314   Thursday     Yes
# 301       Off            On         2.505440   Thursday      No
# ..        ...           ...              ...        ...     ...
# 516       Off            On        20.927287     Friday     Yes
# 758       Off           Off        22.932032   Thursday      No
# 789       Off            On        20.251680     Sunday     Yes
# 111       Off            On        21.162985   Saturday      No
# 972       Off           Off         5.219767     Friday     Yes
#
#      EnergyConsumption
# 826          83.054685
# 507          82.558204
# 457          73.596989
# 281          91.490982
# 301          80.487036
# ..                 ...
# 516          77.263341
# 758          56.849829
# 789          81.743052
# 111          85.360403
# 972          81.385155
#
# [750 rows x 11 columns]
